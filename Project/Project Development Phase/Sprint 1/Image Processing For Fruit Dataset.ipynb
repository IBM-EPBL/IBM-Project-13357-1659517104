# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
pwd
# Out:
# 'C:\\Users\\abiz1'

# %%
train_datagen = ImageDataGenerator (rescale = 1./255, shear_range= 0.2,zoom_range= 0.2, horizontal_flip = True)

# %%
test_datagen =ImageDataGenerator (rescale = 1)

# %%
x_train = train_datagen.flow_from_directory(r'D:\IBM\Dataset Plant Disease\fruit-dataset\fruit-dataset\train',target_size = (128,128), batch_size = 32, class_mode = 'categorical')
x_test = test_datagen.flow_from_directory(r'D:\IBM\Dataset Plant Disease\fruit-dataset\fruit-dataset\test',target_size = (128,128), batch_size = 32, class_mode = 'categorical')
# Out:
# Found 5384 images belonging to 6 classes.
# Found 1686 images belonging to 6 classes.

# %%
import imageio
import matplotlib.pyplot as plt
# %matplotlib inline
pic = imageio.imread(r'D:\IBM\Dataset Plant Disease\fruit-dataset\fruit-dataset\train\Apple___Black_rot\30aebb07-bde6-44c8-bee2-a06ff42a948d___JR_FrgE.S 3071.JPG')
plt.figure(figsize = (5,5))
plt.imshow(pic)
# Out:
# C:\Users\abiz1\AppData\Local\Temp/ipykernel_4368/2530684301.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   pic = imageio.imread(r'D:\IBM\Dataset Plant Disease\fruit-dataset\fruit-dataset\train\Apple___Black_rot\30aebb07-bde6-44c8-bee2-a06ff42a948d___JR_FrgE.S 3071.JPG')

# %%
print('Type of the image : ' , type(pic)) 
print('Shape of the image : {}'.format(pic.shape)) 
print('Image Hight {}'.format(pic.shape[0])) 
print('Image Width {}'.format(pic.shape[1])) 
print('Dimension of Image {}'.format(pic.ndim))
# Out:
# Type of the image :  <class 'imageio.core.util.Array'>
# Shape of the image : (256, 256, 3)
# Image Hight 256
# Image Width 256
# Dimension of Image 3

# %%
print('Image size {}'.format(pic.size)) 
print('Maximum RGB value in this image {}'.format(pic.max())) 
print('Minimum RGB value in this image {}'.format(pic.min()))
# Out:
# Image size 196608
# Maximum RGB value in this image 255
# Minimum RGB value in this image 0

# %%
plt.title('R channel') 
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 0])
plt.show()

# %%
plt.title('G channel')
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 1]) 
plt.show()

# %%
plt.title('B channel') 
plt.ylabel('Height {}'.format(pic.shape[0])) 
plt.xlabel('Width {}'.format(pic.shape[1])) 
plt.imshow(pic[ : , : , 2]) 
plt.show()

# %%
pic[50:150 , : , 0] = 255 # full intensity to those pixel's R channel 
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %%
pic[200:300 , : , 1] = 255 # full intensity to those pixel's G channel 
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %%
pic[350:450 , : , 2] = 255 # full intensity to those pixel's B channel 
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %%
# set value 200 of all channels to those pixels which turns them to white 
pic[ 50:450 , 400:600 , [0,1,2] ] = 200  
plt.figure( figsize = (5,5)) 
plt.imshow(pic) 
plt.show()

# %%
import numpy as np 
pic = imageio.imread(r'D:\IBM\Dataset Plant Disease\fruit-dataset\fruit-dataset\train\Apple___Black_rot\30aebb07-bde6-44c8-bee2-a06ff42a948d___JR_FrgE.S 3071.JPG') 
fig, ax = plt.subplots(nrows = 1, ncols=3, figsize=(15,5))  
for c, ax in zip(range(3), ax):     
     # create zero matrix        
    split_img = np.zeros(pic.shape, dtype="uint8") 
     # 'dtype' by default: 'numpy.float64'  # assing each channel      
    split_img[ :, :, c] = pic[ :, :, c] # display each channel     
    ax.imshow(split_img)
# Out:
# C:\Users\abiz1\AppData\Local\Temp/ipykernel_4368/3279754514.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   pic = imageio.imread(r'D:\IBM\Dataset Plant Disease\fruit-dataset\fruit-dataset\train\Apple___Black_rot\30aebb07-bde6-44c8-bee2-a06ff42a948d___JR_FrgE.S 3071.JPG')
